# %%
import numpy as np
import pandas as pd
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'
dado = np.loadtxt(url, delimiter=',',usecols=np.arange(1,6,1),skiprows=1)

# %%
dado
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
##pegar o diametro[0] e o peso[1]

# %%
diametro = dado[:,0]
peso = dado[:,1]

# %%
diametro
# Out:
# array([ 2.96,  3.91,  4.42, ..., 15.59, 15.92, 16.45])

# %%
peso
# Out:
# array([ 86.76,  88.05,  95.17, ..., 256.5 , 260.14, 261.51])

# %%
## Os dados referentes a laranja vão até a linha 4999 e os referentes à toranja iniciam na linha 5000 do arquivo

# %%
np.shape(diametro)
# Out:
# (10000,)

# %%
laranja_diametro = diametro[:5000]

# %%
laranja_diametro
# Out:
# array([ 2.96,  3.91,  4.42, ..., 12.55, 12.75, 12.87])

# %%
toranja_diametro = diametro[5000:]

# %%
toranja_diametro
# Out:
# array([ 7.63,  7.69,  7.72, ..., 15.59, 15.92, 16.45])

# %%
laranja_peso = peso[:5000]
toranja_peso = peso[5000:]

# %%
laranja_peso
# Out:
# array([ 86.76,  88.05,  95.17, ..., 218.07, 230.13, 231.09])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(laranja_diametro,laranja_peso)

# %%
plt.plot(toranja_diametro,toranja_peso)

# %%
diametro_laranja = dado[:5000,0]
diametro_toranja = dado[5000:,0]
peso_laranja = dado[:5000,1]
peso_toranja = dado[5000:,1]

# %%
plt.plot(diametro_laranja, peso_laranja)
plt.plot(diametro_toranja, peso_toranja)
plt.legend(['laranja','toranja'])

# %%
#Marcando o coeficiente linear da laranja:

# %%
plt.plot(diametro_laranja, peso_laranja)

# %%
X = diametro_laranja
Y = peso_laranja

# %%
a,b = np.polyfit(X,Y,1)

# %%
y = a * X + b

# %%
line = np.linalg.norm(X - y)
line
# Out:
# np.float64(10279.562771217901)

# %%
plt.plot(diametro_laranja,peso_laranja)
plt.plot(y)

# %%
Y = peso_laranja
X = diametro_laranja
n = np.size(X)

a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2)-np.sum(X)**2)
b = np.mean(Y) - a*np.mean(X)

y = a * X + b

plt.plot(X,Y)
